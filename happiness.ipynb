# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\91904\Downloads\WHR26_Data_Figure_2.1.csv")
df
# Out:
#      Year  Rank  Country name  Life evaluation-3 year average  Lower whisker  \
# 0    2025     1       Finland                           7.764          7.690
# 1    2025     2       Iceland                           7.540          7.449
# 2    2025     3       Denmark                           7.539          7.446
# 3    2025     4    Costa Rica                           7.439          7.356
# 4    2025     5        Sweden                           7.255          7.172
# ..    ...   ...           ...                             ...            ...
# 432  2023   139      DR Congo                           3.295          3.128
# 433  2023   140  Sierra Leone                           3.245          3.124
# 434  2023   141       Lesotho                           3.186          2.904
# 435  2023   142       Lebanon                           2.707          2.616
# 436  2023   143   Afghanistan                           1.721          1.667
#
# ...

# %%
len(df[df['Country name']=="Bahrain"])
# Out:
# 3

# %%
len(df[df['Year']==2025])
# Out:
# 147

# %%
len(df[df['Year']==2024])
# Out:
# 147

# %%
len(df[df['Year']==2023])
# Out:
# 143

# %%
Tot_con=[[len(df[df['Year']==2025]), len(df[df['Year']==2024]), len(df[df['Year']==2023])]]
k=pd.DataFrame(Tot_con, columns=["2025","2024","2023"], index=["Total countries"])
k.index.name="Year"
print(k)
# Out:
#                  2025  2024  2023
# Year
# Total countries   147   147   143

# %%
df.filter(items=['Country name', 'Rank'])
# Out:
#      Country name  Rank
# 0         Finland     1
# 1         Iceland     2
# 2         Denmark     3
# 3      Costa Rica     4
# 4          Sweden     5
# ..            ...   ...
# 432      DR Congo   139
# 433  Sierra Leone   140
# 434       Lesotho   141
# 435       Lebanon   142
# 436   Afghanistan   143
#
# [437 rows x 2 columns]

# %%
df['Country name'].where(df['Country name']=='Bahrain')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 432    NaN
# 433    NaN
# 434    NaN
# 435    NaN
# 436    NaN
# Name: Country name, Length: 437, dtype: str

# %%
df.loc[df['Country name']=='Bahrain']
# Out:
#      Year  Rank Country name  Life evaluation-3 year average  Lower whisker  \
# 54   2025    55      Bahrain                           6.254          6.143
# 205  2024    59      Bahrain                           6.030          5.891
# 355  2023    62      Bahrain                           5.959          5.766
#
#      Upper whisker  Log GDP per capita  Social support  \
# 54           6.364               1.930           1.293
# 205          6.170               1.752           1.391
# 355          6.153                 NaN             NaN
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 54                     0.693                         1.055       0.143
# 205                    0.609                         0.907       0.148
# 355                      NaN                           NaN         NaN
#
#      Perceptions of corruption  Dystopia + residual
# 54                       0.171                0.969
# ...

# %%
dd=df[df['Log GDP per capita'].isna()]

# %%
dd
# Out:
#      Year  Rank        Country name  Life evaluation-3 year average  \
# 355  2023    62             Bahrain                           5.959
# 381  2023    88          Tajikistan                           5.281
# 396  2023   103  State of Palestine                           4.879
#
#      Lower whisker  Upper whisker  Log GDP per capita  Social support  \
# 355          5.766          6.153                 NaN             NaN
# 381          5.201          5.361                 NaN             NaN
# 396          4.753          5.006                 NaN             NaN
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 355                      NaN                           NaN         NaN
# 381                      NaN                           NaN         NaN
# 396                      NaN                           NaN         NaN
#
#      Perceptions of corruption  Dystopia + residual
# 355                        NaN                  NaN
# ...

# %%
dd[dd['Country name']=='Bahrain']
# Out:
#      Year  Rank Country name  Life evaluation-3 year average  Lower whisker  \
# 355  2023    62      Bahrain                           5.959          5.766
#
#      Upper whisker  Log GDP per capita  Social support  \
# 355          6.153                 NaN             NaN
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 355                      NaN                           NaN         NaN
#
#      Perceptions of corruption  Dystopia + residual
# 355                        NaN                  NaN

# %%
df['Log GDP per capita']=df['Log GDP per capita'].fillna(df['Log GDP per capita'].mean())

# %%
print(df['Log GDP per capita'])
# Out:
# 0      1.915
# 1      1.971
# 2      1.986
# 3      1.697
# 4      1.950
#        ...
# 432    0.534
# 433    0.654
# 434    0.771
# 435    1.377
# 436    0.628
# Name: Log GDP per capita, Length: 437, dtype: float64

# %%
dd=df[df['Social support'].isna()]

# %%
dd
# Out:
#      Year  Rank        Country name  Life evaluation-3 year average  \
# 355  2023    62             Bahrain                           5.959
# 381  2023    88          Tajikistan                           5.281
# 396  2023   103  State of Palestine                           4.879
#
#      Lower whisker  Upper whisker  Log GDP per capita  Social support  \
# 355          5.766          6.153            1.411329             NaN
# 381          5.201          5.361            1.411329             NaN
# 396          4.753          5.006            1.411329             NaN
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 355                      NaN                           NaN         NaN
# 381                      NaN                           NaN         NaN
# 396                      NaN                           NaN         NaN
#
#      Perceptions of corruption  Dystopia + residual
# 355                        NaN                  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            437 non-null    int64
#  1   Rank                            437 non-null    int64
#  2   Country name                    437 non-null    str
#  3   Life evaluation-3 year average  437 non-null    float64
#  4   Lower whisker                   437 non-null    float64
#  5   Upper whisker                   437 non-null    float64
#  6   Log GDP per capita              437 non-null    float64
#  7   Social support                  434 non-null    float64
#  8   Healthy life expectancy         432 non-null    float64
#  9   Freedom to make life choices    432 non-null    float64
#  10  Generosity                      434 non-null    float64
#  11  Perceptions of corruption       433 non-null    float64
# ...

# %%
df.describe()
# Out:
#               Year        Rank  Life evaluation-3 year average  Lower whisker  \
# count   437.000000  437.000000                      437.000000     437.000000
# mean   2024.009153   73.345538                        5.585730       5.474208
# std       0.815508   42.118575                        1.154143       1.167207
# min    2023.000000    1.000000                        1.364000       1.301000
# 25%    2023.000000   37.000000                        4.674000       4.549000
# 50%    2024.000000   73.000000                        5.846000       5.727000
# 75%    2025.000000  110.000000                        6.492000       6.390000
# max    2025.000000  147.000000                        7.764000       7.690000
#
#        Upper whisker  Log GDP per capita  Social support  \
# count      437.00000          437.000000      434.000000
# mean         5.69722            1.411329        1.225611
# std          1.14202            0.403239        0.355309
# ...

# %%
df['Social support']=df['Social support'].fillna(df['Social support'].median())

# %%
df.isnull().sum()
# Out:
# Year                              0
# Rank                              0
# Country name                      0
# Life evaluation-3 year average    0
# Lower whisker                     0
# Upper whisker                     0
# Log GDP per capita                0
# Social support                    0
# Healthy life expectancy           5
# Freedom to make life choices      5
# Generosity                        3
# Perceptions of corruption         4
# Dystopia + residual               8
# dtype: int64

# %%
df.fillna({'Healthy life expectancy':df['Healthy life expectancy'].median()},inplace=True)
# Out:
#      Year  Rank  Country name  Life evaluation-3 year average  Lower whisker  \
# 0    2025     1       Finland                           7.764          7.690
# 1    2025     2       Iceland                           7.540          7.449
# 2    2025     3       Denmark                           7.539          7.446
# 3    2025     4    Costa Rica                           7.439          7.356
# 4    2025     5        Sweden                           7.255          7.172
# ..    ...   ...           ...                             ...            ...
# 432  2023   139      DR Congo                           3.295          3.128
# 433  2023   140  Sierra Leone                           3.245          3.124
# 434  2023   141       Lesotho                           3.186          2.904
# 435  2023   142       Lebanon                           2.707          2.616
# 436  2023   143   Afghanistan                           1.721          1.667
#
# ...

# %%
df.loc[df['Country name']=='Bahrain']
# Out:
#      Year  Rank Country name  Life evaluation-3 year average  Lower whisker  \
# 54   2025    55      Bahrain                           6.254          6.143
# 205  2024    59      Bahrain                           6.030          5.891
# 355  2023    62      Bahrain                           5.959          5.766
#
#      Upper whisker  Log GDP per capita  Social support  \
# 54           6.364            1.930000          1.2930
# 205          6.170            1.752000          1.3910
# 355          6.153            1.411329          1.3155
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 54                     0.693                         1.055       0.143
# 205                    0.609                         0.907       0.148
# 355                    0.564                           NaN         NaN
#
#      Perceptions of corruption  Dystopia + residual
# 54                       0.171                0.969
# ...

# %%
df.fillna({'Freedom to make life choices':df['Freedom to make life choices'].median()},inplace=True)
# Out:
#      Year  Rank  Country name  Life evaluation-3 year average  Lower whisker  \
# 0    2025     1       Finland                           7.764          7.690
# 1    2025     2       Iceland                           7.540          7.449
# 2    2025     3       Denmark                           7.539          7.446
# 3    2025     4    Costa Rica                           7.439          7.356
# 4    2025     5        Sweden                           7.255          7.172
# ..    ...   ...           ...                             ...            ...
# 432  2023   139      DR Congo                           3.295          3.128
# 433  2023   140  Sierra Leone                           3.245          3.124
# 434  2023   141       Lesotho                           3.186          2.904
# 435  2023   142       Lebanon                           2.707          2.616
# 436  2023   143   Afghanistan                           1.721          1.667
#
# ...

# %%
df.fillna({'Generosity':df['Generosity'].median()},inplace=True)
# Out:
#      Year  Rank  Country name  Life evaluation-3 year average  Lower whisker  \
# 0    2025     1       Finland                           7.764          7.690
# 1    2025     2       Iceland                           7.540          7.449
# 2    2025     3       Denmark                           7.539          7.446
# 3    2025     4    Costa Rica                           7.439          7.356
# 4    2025     5        Sweden                           7.255          7.172
# ..    ...   ...           ...                             ...            ...
# 432  2023   139      DR Congo                           3.295          3.128
# 433  2023   140  Sierra Leone                           3.245          3.124
# 434  2023   141       Lesotho                           3.186          2.904
# 435  2023   142       Lebanon                           2.707          2.616
# 436  2023   143   Afghanistan                           1.721          1.667
#
# ...

# %%
#df.fillna({'Generosity':df['Generosity'].median()},inplace=True)

df[df["Country name"]=="Tajikistan"]
# Out:
#      Year  Rank Country name  Life evaluation-3 year average  Lower whisker  \
# 87   2025    88   Tajikistan                           5.591          5.513
# 236  2024    90   Tajikistan                           5.411          5.337
# 381  2023    88   Tajikistan                           5.281          5.201
#
#      Upper whisker  Log GDP per capita  Social support  \
# 87           5.669            1.180000          1.4760
# 236          5.485            0.914000          1.5550
# 381          5.361            1.411329          1.3155
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 87                     0.783                         0.767      0.0850
# 236                    0.658                         0.767      0.0850
# 381                    0.564                         0.767      0.1155
#
#      Perceptions of corruption  Dystopia + residual
# 87                       0.336                  NaN
# ...
