# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\91904\Downloads\WHR26_Data_Figure_2.1.csv")
df
# Out:
#      Year  Rank  Country name  Life evaluation-3 year average  Lower whisker  \
# 0    2025     1       Finland                           7.764          7.690
# 1    2025     2       Iceland                           7.540          7.449
# 2    2025     3       Denmark                           7.539          7.446
# 3    2025     4    Costa Rica                           7.439          7.356
# 4    2025     5        Sweden                           7.255          7.172
# ..    ...   ...           ...                             ...            ...
# 432  2023   139      DR Congo                           3.295          3.128
# 433  2023   140  Sierra Leone                           3.245          3.124
# 434  2023   141       Lesotho                           3.186          2.904
# 435  2023   142       Lebanon                           2.707          2.616
# 436  2023   143   Afghanistan                           1.721          1.667
#
# ...

# %%
len(df[df['Country name']=="Bahrain"])
# Out:
# 3

# %%
len(df[df['Year']==2025])
# Out:
# 147

# %%
len(df[df['Year']==2024])
# Out:
# 147

# %%
len(df[df['Year']==2023])
# Out:
# 143

# %%
Tot_con=[[len(df[df['Year']==2025]) & (df[df['Year']==2024]) & (df[df['Year']==2023])]]
k=pd.DataFrame(Tot_con, columns=["2025","2024","2023"])
print(k)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\construction.py:911, in _finalize_columns_and_data(content, columns, dtype)
#     910 try:
# --> 911     columns = _validate_or_indexify_columns(contents, columns)
#     912 except AssertionError as err:
#     913     # GH#26429 do not raise user-facing AssertionError
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\construction.py:958, in _validate_or_indexify_columns(content, columns)
#     956 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     957     # caller's responsibility to check for this...
# --> 958     raise AssertionError(
#     959         f"{len(columns)} columns passed, passed data had {len(content)} columns"
#     960     )
#     961 if is_mi_list:
# ...
