# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\91904\Downloads\titanic\test2.csv")

# %%
print(df)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         1
# 417         1
#
# [418 rows x 12 columns]

# %%
len(df[df["Survived"]==1])
# Out:
# 163

# %%
len(df[df["Survived"]==0])
# Out:
# 255

# %%
df[['Pclass','Survived']]
# Out:
#      Pclass  Survived
# 0         3         0
# 1         3         1
# 2         2         1
# 3         3         1
# 4         3         0
# ..      ...       ...
# 413       3         0
# 414       1         1
# 415       3         0
# 416       3         1
# 417       3         1
#
# [418 rows x 2 columns]

# %%
len(df[df.Pclass==3])
# Out:
# 218

# %%
# df['Pclass==1'] where df['Survived==1']

# %%
len(df[(df['Pclass']==1) & (df['Survived']==0)])
# Out:
# 71

# %%
len(df[(df['Pclass']==3) & (df['Survived']==0)])
# Out:
# 131

# %%
len(df[(df['Pclass']==1) & (df['Age']>18) & (df['Survived']==0)])
# Out:
# 60

# %%
Data = [10,20,30]
datatable=pd.DataFrame(Data)
datatable
# Out:
#     0
# 0  10
# 1  20
# 2  30

# %%
Data = [[10,20,30],[10,20,30]]
datatable=pd.DataFrame(Data, columns=["Number","Age","phone"], index=["A","B"])
datatable
# Out:
#    Number  Age  phone
# A      10   20     30
# B      10   20     30

# %%
Above18=[[len(df[(df['Pclass']==1) & (df['Age']>18) & (df['Survived']==1)]),len(df[(df['Pclass']==2) & (df['Age']>18) & (df['Survived']==1)]),len(df[(df['Pclass']==3) & (df['Age']>18) & (df['Survived']==1)])],[len(df[(df['Pclass']==1) & (df['Age']>18) & (df['Survived']==0)]),len(df[(df['Pclass']==2) & (df['Age']>18) & (df['Survived']==0)]),len(df[(df['Pclass']==3) & (df['Age']>18) & (df['Survived']==0)])]]
c=pd.DataFrame(Above18, columns=["class1", "class2", "class3"], index=["survived","unsurvived"])
c.index.name="Above18"
print(c)
# Out:
#             class1  class2  class3
# Above18
# survived        33      34      43
# unsurvived      60      41      67

# %%
Below18=[[len(df[(df['Pclass']==1) & (df['Age']<18) & (df['Survived']==1)]),len(df[(df['Pclass']==2) & (df['Age']<18) & (df['Survived']==1)]),len(df[(df['Pclass']==3) & (df['Age']<18) & (df['Survived']==1)])],[len(df[(df['Pclass']==1) & (df['Age']<18) & (df['Survived']==0)]),len(df[(df['Pclass']==2) & (df['Age']<18) & (df['Survived']==0)]),len(df[(df['Pclass']==3) & (df['Age']<18) & (df['Survived']==0)])]]
c=pd.DataFrame(Below18, columns=["class1", "class2", "class3"], index=["survived","unsurvived"])
c.index.name="Below18"
print(c)
# Out:
#             class1  class2  class3
# Below18
# survived         0       2      12
# unsurvived       3       8      16

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    str
#  3   Sex          418 non-null    str
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    str
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     str
#  10  Embarked     418 non-null    str
#  11  Survived     418 non-null    int64
# dtypes: float64(2), int64(5), str(5)
# memory usage: 39.3 KB

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   418.000000  418.000000  332.000000  418.000000  418.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344
# std     120.810458    0.841838   14.181209    0.896760    0.981429
# min     892.000000    1.000000    0.170000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000
#
#              Fare    Survived
# count  417.000000  418.000000
# mean    35.627188    0.389952
# std     55.907576    0.488324
# min      0.000000    0.000000
# 25%      7.895800    0.000000
# 50%     14.454200    0.000000
# 75%     31.500000    1.000000
# max    512.329200    1.000000

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
df.fillna({'Age':df['Age'].median()},inplace=True)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male  27.0      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male  27.0      0      0              359309    8.0500   NaN        S
# 417    male  27.0      1      1                2668   22.3583   NaN        C
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         1
# 417         1
#
# [418 rows x 12 columns]

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# Survived       0
# FamilySize     0
# dtype: int64

# %%
df['FamilySize']=df['SibSp']+df['Parch']+1

# %%
df['IsAlone']=(df['FamilySize']==1).astype(int)

# %%
df['AgeGroup']=pd.cut(df['Age'], bins=[0,10,20,40,60,100], labels=['Child','Teen','Adult','Midage','Senior'])

# %%
df['FareGroup']=pd.qcut(df['Fare'],4,labels=['Low','Medium','High','VeryHigh'])

# %%
df['Title']=df['Name'].str.extract(' ([A-Za-z]+)\\.', expand=False)

# %%
print("AgeGroup distribution: ")
print(df['AgeGroup'].value_counts())
# Out:
# AgeGroup distribution:
# AgeGroup
# Adult     272
# Midage     66
# Teen       47
# Child      22
# Senior     11
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# 0      male  34.5      0      0              330911    7.8292        Q
# 1    female  47.0      1      0              363272    7.0000        S
# 2      male  62.0      0      0              240276    9.6875        Q
# 3      male  27.0      0      0              315154    8.6625        S
# 4    female  22.0      1      1             3101298   12.2875        S
# ..      ...   ...    ...    ...                 ...       ...      ...
# 413    male  27.0      0      0           A.5. 3236    8.0500        S
# 414  female  39.0      0      0            PC 17758  108.9000        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male  27.0      0      0              359309    8.0500        S
# 417    male  27.0      1      1                2668   22.3583        C
#
#      Survived  FamilySize  IsAlone AgeGroup FareGroup   Title
# 0           0           1        1    Adult       Low      Mr
# 1           1           2        0   Midage       Low     Mrs
# 2           1           1        1   Senior    Medium      Mr
# 3           1           1        1    Adult    Medium      Mr
# 4           0           3        0    Adult    Medium     Mrs
# ..        ...         ...      ...      ...       ...     ...
# 413         0           1        1    Adult    Medium      Mr
# 414         1           1        1    Adult  VeryHigh    Dona
# 415         0           1        1    Adult       Low      Mr
# 416         1           1        1    Adult    Medium      Mr
# 417         1           3        0    Adult      High  Master
#
# [418 rows x 16 columns]

# %%
len(df[(df['Sex']=='Male') & (df['Age']>0)])
# Out:
# 0

# %%
len(df[df['Sex']=='male'])
# Out:
# 266

# %%
len(df[df['Sex']=='female'])
# Out:
# 152

# %%
df.groupby("Sex").count()['PassengerId']
# Out:
# Sex
# female    152
# male      266
# Name: PassengerId, dtype: int64

# %%
df.groupby("Age").count()['PassengerId']
# Out:
# Age
# 0.17     1
# 0.33     1
# 0.75     1
# 0.83     1
# 0.92     1
#         ..
# 62.00    1
# 63.00    2
# 64.00    3
# 67.00    1
# 76.00    1
# Name: PassengerId, Length: 79, dtype: int64

# %%
df.groupby("AgeGroup").count()['PassengerId']
# Out:
# AgeGroup
# Child      22
# Teen       47
# Adult     272
# Midage     66
# Senior     11
# Name: PassengerId, dtype: int64
